# %%
import pandas as pd

# %%
c= pd.read_csv('Downloads/c.csv')
c
# Out:
#      Unnamed: 0              Group     Campus  District         DistName  \
# 0             0              Asian    2901001      2901      Andrews ISD
# 1             1        Multiracial   13901001     13901     Beeville ISD
# 2             2  Missing Ethnicity   13901001     13901     Beeville ISD
# 3             3              Asian   14908001     14908       Salado ISD
# 4             4    American Indian   15907023     15907  San Antonio ISD
# ..          ...                ...        ...       ...              ...
# 220         220         Special Ed  236902008    236902   Huntsville ISD
# 221         221            Migrant  240901002    240901       Laredo ISD
# 222         222   African American  252901001    252901       Graham ISD
# 223         223    American Indian  252901001    252901       Graham ISD
# 224         224              Asian  252901001    252901       Graham ISD
#
#      Region  SAT_Reading  SAT_Math  Total  Above_Crit_Rate  \
# ...

# %%
d= pd.read_csv('Downloads/d.csv')
d
# Out:
#      Unnamed: 0              Group  District           DistName  Region  \
# 0             0              Asian      2901        Andrews ISD      18
# 1             1        Multiracial     13901       Beeville ISD       2
# 2             2  Missing Ethnicity     13901       Beeville ISD       2
# 3             3              Asian     14908         Salado ISD      12
# 4             4        Multiracial     17901  Borden County ISD      17
# ..          ...                ...       ...                ...     ...
# 156         156    American Indian    227913    Lake Travis ISD      13
# 157         157             Gifted    229901     Colmesneil ISD       5
# 158         158   African American    252901         Graham ISD       9
# 159         159    American Indian    252901         Graham ISD       9
# 160         160              Asian    252901         Graham ISD       9
#
#      SAT_Reading  SAT_Math  Total  Above_Crit_Rate  Above_TSI_Both_Rate  \
# ...

# %%
c.shape
# Out:
# (225, 18)

# %%
d.shape
# Out:
# (161, 17)

# %%
dc= pd.concat([c,d], axis="columns")
dc
# Out:
#      Unnamed: 0              Group     Campus  District         DistName  \
# 0             0              Asian    2901001      2901      Andrews ISD
# 1             1        Multiracial   13901001     13901     Beeville ISD
# 2             2  Missing Ethnicity   13901001     13901     Beeville ISD
# 3             3              Asian   14908001     14908       Salado ISD
# 4             4    American Indian   15907023     15907  San Antonio ISD
# ..          ...                ...        ...       ...              ...
# 220         220         Special Ed  236902008    236902   Huntsville ISD
# 221         221            Migrant  240901002    240901       Laredo ISD
# 222         222   African American  252901001    252901       Graham ISD
# 223         223    American Indian  252901001    252901       Graham ISD
# 224         224              Asian  252901001    252901       Graham ISD
#
#      Region  SAT_Reading  SAT_Math  Total  Above_Crit_Rate  ...   Total  \
# ...

# %%
dc.to_csv('dc.csv')

# %%
# !pip install geopandas
