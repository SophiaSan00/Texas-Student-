# %% [markdown]
# # Predicting Student's Performance and SAT/ACT result
#
# ## Using the model from satact-campus-data-class-2021

# %% [markdown]
# Students in Public

# %%
#These are the libaray that was use for the car crash. I need to check closely with the data and see which of the libaries will beneifit the result of the topic. 
#These are libaray for the start but I may add new library, delete some of the library, or keep the library that is necessary for the project
import numpy as np
import pandas as pd 
from sklearn.model_selection import train_test_split
from sklearn import linear_model
from sklearn.neighbors import KNeighborsRegressor
from sklearn.preprocessing import PolynomialFeatures
from sklearn import metrics
from sklearn.cluster import AffinityPropagation
from sklearn.datasets import make_blobs
from sklearn.preprocessing import LabelEncoder 
from sklearn.model_selection import cross_val_score
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import preprocessing
from sklearn.naive_bayes import GaussianNB
from kmodes.kmodes import KModes

#Ploty Packages
from plotly import tools
import plotly.figure_factory as ff
import plotly.graph_objs as go

#Mathplotlib
import matplotlib.pyplot as plt
from string import ascii_letters

#Statistical Libraries 
from scipy.stats import norm
from scipy.stats import skew
from scipy.stats.stats import pearsonr
from scipy import stats
# %matplotlib inline

#Interative Map 
from bokeh.plotting import figure, show 
from bokeh.io import output_notebook

# %% [markdown]
# # SAT/ACT Campus Level

# %%
ty = pd.read_csv('Downloads/SATTexas2021campus.csv')
ty.fillna(method= 'ffill', inplace=True)
print(ty.head())
result = ty.dtypes
print(result)
# Out:
#               Group   Campus  AICode    CampName  District    DistName  \
# 0      All Students  1902001  441165  Cayuga H S      1902  Cayuga ISD
# 1  African American  1902001  441165  Cayuga H S      1902  Cayuga ISD
# 2   American Indian  1902001  441165  Cayuga H S      1902  Cayuga ISD
# 3             Asian  1902001  441165  Cayuga H S      1902  Cayuga ISD
# 4          Hispanic  1902001  441165  Cayuga H S      1902  Cayuga ISD
#
#    County         CntyName  Region RegnName    ERW   Math  Total Grads_Mskd  \
# 0       1  Anderson County       7  Kilgore  503.0  476.0  980.0        <50
# 1       1  Anderson County       7  Kilgore  503.0  476.0  980.0        <25
# 2       1  Anderson County       7  Kilgore  503.0  476.0  980.0        <25
# 3       1  Anderson County       7  Kilgore  503.0  476.0  980.0        <25
# 4       1  Anderson County       7  Kilgore  467.0  433.0  900.0        <25
#
#   Exnees_Mskd  Part_Rate Crit_Mskd  Above_Crit_Rate TSI_Both_Mskd  \
# 0         <25       58.3       <25             19.0           <25
# 1         <25       50.0       <25             19.0           <25
# 2         <25       50.0       <25             19.0           <25
# 3         <25       50.0       <25             19.0           <25
# 4         <25      100.0       <25             19.0           <25
#
#    Above_TSI_Both_Rate
# 0                 19.0
# 1                 19.0
# 2                 19.0
# 3                 19.0
# 4                 19.0
# Group                   object
# Campus                   int64
# AICode                   int64
# CampName                object
# District                 int64
# DistName                object
# County                   int64
# CntyName                object
# Region                   int64
# RegnName                object
# ERW                    float64
# Math                   float64
# Total                  float64
# Grads_Mskd              object
# Exnees_Mskd             object
# Part_Rate              float64
# Crit_Mskd               object
# Above_Crit_Rate        float64
# TSI_Both_Mskd           object
# Above_TSI_Both_Rate    float64
# dtype: object

# %%
rt = pd.read_csv('Downloads/ACTTexas2021campus.csv')
rt.fillna(method= 'ffill', inplace=True)
print(rt.head())
result = rt.dtypes
print(result)
# Out:
#               Group   Campus  AICode     CampName  District     DistName  \
# 0      All Students  1903001  442190  Elkhart H S      1903  Elkhart ISD
# 1  African American  1903001  442190  Elkhart H S      1903  Elkhart ISD
# 2   American Indian  1903001  442190  Elkhart H S      1903  Elkhart ISD
# 3             Asian  1903001  442190  Elkhart H S      1903  Elkhart ISD
# 4          Hispanic  1903001  442190  Elkhart H S      1903  Elkhart ISD
#
#    County         CntyName  Region RegnName  ...  Reading  Science  Compos  \
# 0       1  Anderson County       7  Kilgore  ...     20.0     22.5    20.5
# 1       1  Anderson County       7  Kilgore  ...     20.0     22.5    20.5
# 2       1  Anderson County       7  Kilgore  ...     20.0     22.5    20.5
# 3       1  Anderson County       7  Kilgore  ...     20.0     22.5    20.5
# 4       1  Anderson County       7  Kilgore  ...     20.0     22.5    20.5
#
#    Grads_Mskd  Exnees_Mskd Part_Rate Crit_Mskd  Above_Crit_Rate TSI_Both_Mskd  \
# 0        <100          <25       2.2       <25              NaN           <25
# 1         <25          <25       2.2       <25              NaN           <25
# 2         <25          <25       2.2       <25              NaN           <25
# 3         <25          <25       2.2       <25              NaN           <25
# 4         <25          <25       2.2       <25              NaN           <25
#
#    Above_TSI_Both_Rate
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
#
# [5 rows x 22 columns]
# Group                   object
# Campus                   int64
# AICode                   int64
# CampName                object
# District                 int64
# DistName                object
# County                   int64
# CntyName                object
# Region                   int64
# RegnName                object
# English                float64
# Math                   float64
# Reading                float64
# Science                float64
# Compos                 float64
# Grads_Mskd              object
# Exnees_Mskd             object
# Part_Rate              float64
# Crit_Mskd               object
# Above_Crit_Rate        float64
# TSI_Both_Mskd           object
# Above_TSI_Both_Rate    float64
# dtype: object

# %%
ct = pd.read_csv('Downloads/SATACTTexas2021campus.csv')
ct.fillna(method= 'ffill', inplace=True)
print(ct.head())
results = ct.dtypes
print(results)
# Out:
#               Group   Campus  AICode    CampName  District    DistName  \
# 0      All Students  1902001  441165  Cayuga H S      1902  Cayuga ISD
# 1  African American  1902001  441165  Cayuga H S      1902  Cayuga ISD
# 2   American Indian  1902001  441165  Cayuga H S      1902  Cayuga ISD
# 3             Asian  1902001  441165  Cayuga H S      1902  Cayuga ISD
# 4          Hispanic  1902001  441165  Cayuga H S      1902  Cayuga ISD
#
#    County         CntyName  Region RegnName Grads_Mskd Exnees_Mskd  Part_Rate  \
# 0       1  Anderson County       7  Kilgore        <50         <25       58.3
# 1       1  Anderson County       7  Kilgore        <25         <25       50.0
# 2       1  Anderson County       7  Kilgore        <25         <25       50.0
# 3       1  Anderson County       7  Kilgore        <25         <25       50.0
# 4       1  Anderson County       7  Kilgore        <25         <25      100.0
#
#   Crit_Mskd  Above_Crit_Rate TSI_Both_Mskd  Above_TSI_Both_Rate
# 0       <25             19.0           <25                 19.0
# 1       <25             19.0           <25                 19.0
# 2       <25             19.0           <25                 19.0
# 3       <25             19.0           <25                 19.0
# 4       <25             19.0           <25                 19.0
# Group                   object
# Campus                   int64
# AICode                   int64
# CampName                object
# District                 int64
# DistName                object
# County                   int64
# CntyName                object
# Region                   int64
# RegnName                object
# Grads_Mskd              object
# Exnees_Mskd             object
# Part_Rate              float64
# Crit_Mskd               object
# Above_Crit_Rate        float64
# TSI_Both_Mskd           object
# Above_TSI_Both_Rate    float64
# dtype: object

# %%
#Merging SAT, ACT, SAT/ACT Campus Level DistName,County,CntyName,Region,RegnName
#Grads_Mskd,Exnees_Mskd,Part_Rate,Crit_Mskd,Above_Crit_Rate,TSI_Both_Mskd,Above_TSI_Both_Rate

c = pd.merge(pd.merge(ty,rt,on=['Group','Campus','CampName','AICode','District','DistName','County','CntyName','Region','RegnName','Grads_Mskd','Exnees_Mskd','Part_Rate','Crit_Mskd','Above_Crit_Rate','TSI_Both_Mskd','Above_TSI_Both_Rate']),ct,on=['Group','Campus','CampName','AICode','District','DistName','County','CntyName','Region','RegnName','Grads_Mskd','Exnees_Mskd','Part_Rate','Crit_Mskd','Above_Crit_Rate','TSI_Both_Mskd','Above_TSI_Both_Rate'])
print(c.fillna(method='ffill', inplace =True))
c.drop(['AICode','CampName','CntyName','DistName','County','RegnName','Part_Rate','Crit_Mskd','Grads_Mskd','TSI_Both_Mskd','Exnees_Mskd'],axis=1,inplace=True)
c.rename(columns={"Math_x":"SAT_Math","Math_y":"ACT_Math","ERW":"SAT_Reading"}, inplace=True)
print(c)
c.isnull().values.any()
# Out:
# None
#                  Group     Campus  District  Region  SAT_Reading  SAT_Math  \
# 0                Asian    2901001      2901      18        525.0     516.0
# 1          Multiracial   13901001     13901       2        580.0     530.0
# 2    Missing Ethnicity   13901001     13901       2        580.0     530.0
# 3                Asian   14908001     14908      12        583.0     559.0
# 4      American Indian   15907023     15907      20        588.0     573.0
# ..                 ...        ...       ...     ...          ...       ...
# 220         Special Ed  236902008    236902       6        490.0     475.0
# 221            Migrant  240901002    240901       1        555.0     605.0
# 222   African American  252901001    252901       9        535.0     529.0
# 223    American Indian  252901001    252901       9        535.0     529.0
# 224              Asian  252901001    252901       9        535.0     529.0
#
#       Total  Above_Crit_Rate  Above_TSI_Both_Rate  English  ACT_Math  Reading  \
# 0    1041.0            100.0                100.0     20.8      21.6     23.5
# 1    1110.0             33.3                 33.3     25.0      21.7     25.7
# 2    1110.0             33.3                 33.3     25.0      21.7     25.7
# 3    1142.0            100.0                100.0     22.8      25.2     25.7
# 4    1161.0            100.0                100.0     24.3      24.1     25.2
# ..      ...              ...                  ...      ...       ...      ...
# 220   965.0            100.0                100.0     21.9      21.1     24.8
# 221  1160.0             50.0                 50.0     18.0      23.0     23.5
# 222  1065.0            100.0                100.0     20.1      22.3     23.3
# 223  1065.0            100.0                100.0     20.1      22.3     23.3
# 224  1065.0            100.0                100.0     20.1      22.3     23.3
#
#      Science  Compos
# 0       22.7    22.3
# 1       21.0    23.3
# 2       21.0    23.3
# 3       25.6    25.0
# 4       23.7    24.3
# ..       ...     ...
# 220     23.5    22.9
# 221     21.5    21.5
# 222     23.5    22.4
# 223     23.5    22.4
# 224     23.5    22.4
#
# [225 rows x 14 columns]
# False

# %% [markdown]
# ### Combing the two data together

# %% [markdown]
# # SAT/ ACT District Data

# %%
sa = pd.read_csv('Downloads/SATTexas2021district.csv')
sa.fillna(method= 'ffill', inplace=True)
print(sa.head())
result = sa.dtypes
print(result)
# Out:
#               Group  District    DistName  County         CntyName  Region  \
# 0      All Students      1902  Cayuga ISD       1  Anderson County       7
# 1  African American      1902  Cayuga ISD       1  Anderson County       7
# 2   American Indian      1902  Cayuga ISD       1  Anderson County       7
# 3             Asian      1902  Cayuga ISD       1  Anderson County       7
# 4          Hispanic      1902  Cayuga ISD       1  Anderson County       7
#
#   RegnName    ERW   Math  Total Grads_Mskd Exnees_Mskd  Part_Rate Crit_Mskd  \
# 0  Kilgore  503.0  476.0  980.0        <50         <25       58.3       <25
# 1  Kilgore  503.0  476.0  980.0        <25         <25       50.0       <25
# 2  Kilgore  503.0  476.0  980.0        <25         <25       50.0       <25
# 3  Kilgore  503.0  476.0  980.0        <25         <25       50.0       <25
# 4  Kilgore  467.0  433.0  900.0        <25         <25      100.0       <25
#
#    Above_Crit_Rate TSI_Both_Mskd  Above_TSI_Both_Rate
# 0             19.0           <25                 19.0
# 1             19.0           <25                 19.0
# 2             19.0           <25                 19.0
# 3             19.0           <25                 19.0
# 4             19.0           <25                 19.0
# Group                   object
# District                 int64
# DistName                object
# County                   int64
# CntyName                object
# Region                   int64
# RegnName                object
# ERW                    float64
# Math                   float64
# Total                  float64
# Grads_Mskd              object
# Exnees_Mskd             object
# Part_Rate              float64
# Crit_Mskd               object
# Above_Crit_Rate        float64
# TSI_Both_Mskd           object
# Above_TSI_Both_Rate    float64
# dtype: object

# %%
er = pd.read_csv('Downloads/ACTTexas2021district.csv')
er.fillna(method= 'ffill', inplace=True)
print(er.head())
result = er.dtypes
print(result)
# Out:
#               Group  District     DistName  County         CntyName  Region  \
# 0      All Students      1903  Elkhart ISD       1  Anderson County       7
# 1  African American      1903  Elkhart ISD       1  Anderson County       7
# 2   American Indian      1903  Elkhart ISD       1  Anderson County       7
# 3             Asian      1903  Elkhart ISD       1  Anderson County       7
# 4          Hispanic      1903  Elkhart ISD       1  Anderson County       7
#
#   RegnName  English  Math  Reading  Science  Compos Grads_Mskd Exnees_Mskd  \
# 0  Kilgore     20.0  19.0     20.0     22.5    20.5       <100         <25
# 1  Kilgore     20.0  19.0     20.0     22.5    20.5        <25         <25
# 2  Kilgore     20.0  19.0     20.0     22.5    20.5        <25         <25
# 3  Kilgore     20.0  19.0     20.0     22.5    20.5        <25         <25
# 4  Kilgore     20.0  19.0     20.0     22.5    20.5        <25         <25
#
#    Part_Rate Crit_Mskd  Above_Crit_Rate TSI_Both_Mskd  Above_TSI_Both_Rate
# 0        2.2       <25              NaN           <25                  NaN
# 1        2.2       <25              NaN           <25                  NaN
# 2        2.2       <25              NaN           <25                  NaN
# 3        2.2       <25              NaN           <25                  NaN
# 4        2.2       <25              NaN           <25                  NaN
# Group                   object
# District                 int64
# DistName                object
# County                   int64
# CntyName                object
# Region                   int64
# RegnName                object
# English                float64
# Math                   float64
# Reading                float64
# Science                float64
# Compos                 float64
# Grads_Mskd              object
# Exnees_Mskd             object
# Part_Rate              float64
# Crit_Mskd               object
# Above_Crit_Rate        float64
# TSI_Both_Mskd           object
# Above_TSI_Both_Rate    float64
# dtype: object

# %%
tt = pd.read_csv('Downloads/SATACTTexas2021district.csv')
tt.fillna(method= 'ffill', inplace=True)
print(tt.head())
results = tt.dtypes
print(results)
# Out:
#               Group  District    DistName  County         CntyName  Region  \
# 0      All Students      1902  Cayuga ISD       1  Anderson County       7
# 1  African American      1902  Cayuga ISD       1  Anderson County       7
# 2   American Indian      1902  Cayuga ISD       1  Anderson County       7
# 3             Asian      1902  Cayuga ISD       1  Anderson County       7
# 4          Hispanic      1902  Cayuga ISD       1  Anderson County       7
#
#   RegnName Grads_Mskd Exnees_Mskd  Part_Rate Crit_Mskd  Above_Crit_Rate  \
# 0  Kilgore        <50         <25       58.3       <25             19.0
# 1  Kilgore        <25         <25       50.0       <25             19.0
# 2  Kilgore        <25         <25       50.0       <25             19.0
# 3  Kilgore        <25         <25       50.0       <25             19.0
# 4  Kilgore        <25         <25      100.0       <25             19.0
#
#   TSI_Both_Mskd  Above_TSI_Both_Rate
# 0           <25                 19.0
# 1           <25                 19.0
# 2           <25                 19.0
# 3           <25                 19.0
# 4           <25                 19.0
# Group                   object
# District                 int64
# DistName                object
# County                   int64
# CntyName                object
# Region                   int64
# RegnName                object
# Grads_Mskd              object
# Exnees_Mskd             object
# Part_Rate              float64
# Crit_Mskd               object
# Above_Crit_Rate        float64
# TSI_Both_Mskd           object
# Above_TSI_Both_Rate    float64
# dtype: object

# %%
#Merging SAT, ACT, SAT/ACT District Level

d = pd.merge(pd.merge(sa,er,on=['Group','District','DistName','County','CntyName','Region','RegnName','Grads_Mskd','Exnees_Mskd','Part_Rate','Crit_Mskd','Above_Crit_Rate','TSI_Both_Mskd','Above_TSI_Both_Rate']),tt,on=['Group','District','DistName','County','CntyName','Region','RegnName','Grads_Mskd','Exnees_Mskd','Part_Rate','Crit_Mskd','Above_Crit_Rate','TSI_Both_Mskd','Above_TSI_Both_Rate'])
print(d.fillna(method='ffill', inplace =True))
d.drop(['CntyName','DistName','County','RegnName','Part_Rate','Crit_Mskd','Grads_Mskd','TSI_Both_Mskd','Exnees_Mskd'],axis=1,inplace=True)
d.rename(columns={"Math_x":"SAT_Math","Math_y":"ACT_Math","ERW":"SAT_Reading"}, inplace=True)
print(d)
d.isnull().values.any()
# Out:
# None
#                  Group  District  Region  SAT_Reading  SAT_Math   Total  \
# 0                Asian      2901      18        525.0     516.0  1041.0
# 1          Multiracial     13901       2        580.0     530.0  1110.0
# 2    Missing Ethnicity     13901       2        580.0     530.0  1110.0
# 3                Asian     14908      12        583.0     559.0  1142.0
# 4          Multiracial     17901      17        626.0     563.0  1189.0
# ..                 ...       ...     ...          ...       ...     ...
# 156    American Indian    227913      13        520.0     472.0   992.0
# 157             Gifted    229901       5        590.0     465.0  1055.0
# 158   African American    252901       9        535.0     529.0  1065.0
# 159    American Indian    252901       9        535.0     529.0  1065.0
# 160              Asian    252901       9        535.0     529.0  1065.0
#
#      Above_Crit_Rate  Above_TSI_Both_Rate  English  ACT_Math  Reading  \
# 0              100.0                100.0     20.8      21.6     23.5
# 1               33.3                 33.3     25.0      21.7     25.7
# 2               33.3                 33.3     25.0      21.7     25.7
# 3              100.0                100.0     22.8      25.2     25.7
# 4              100.0                100.0     22.8      22.4     25.6
# ..               ...                  ...      ...       ...      ...
# 156            100.0                100.0     19.0      19.0     23.7
# 157            100.0                100.0     19.6      18.9     21.9
# 158            100.0                100.0     20.1      22.3     23.3
# 159            100.0                100.0     20.1      22.3     23.3
# 160            100.0                100.0     20.1      22.3     23.3
#
#      Science  Compos
# 0       22.7    22.3
# 1       21.0    23.3
# 2       21.0    23.3
# 3       25.6    25.0
# 4       23.9    23.8
# ..       ...     ...
# 156     20.3    20.7
# 157     20.4    20.3
# 158     23.5    22.4
# 159     23.5    22.4
# 160     23.5    22.4
#
# [161 rows x 13 columns]
# False

# %%
d.to_csv('d.csv', index=False)
c.to_csv('c.csv', index=False)

# %% [markdown]
# # Check for missing data

# %%
#Visuallization
import missingno as msno

# %%
#Check if there is missing data in the SAT/ACT district
msno.matrix(c)
# Out:
# <AxesSubplot:>

# %%
msno.matrix(d)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Descriptive Stats of Distrcit Level

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
print(d.shape)
print(d.info())
# Out:
# (161, 13)
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 161 entries, 0 to 160
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Group                161 non-null    object
#  1   District             161 non-null    int64
#  2   Region               161 non-null    int64
#  3   SAT_Reading          161 non-null    float64
#  4   SAT_Math             161 non-null    float64
#  5   Total                161 non-null    float64
#  6   Above_Crit_Rate      161 non-null    float64
#  7   Above_TSI_Both_Rate  161 non-null    float64
#  8   English              161 non-null    float64
#  9   ACT_Math             161 non-null    float64
#  10  Reading              161 non-null    float64
#  11  Science              161 non-null    float64
#  12  Compos               161 non-null    float64
# dtypes: float64(10), int64(2), object(1)
# memory usage: 17.6+ KB
# None

# %%
d.describe(include='all')
# Out:
#          Group       District      Region  SAT_Reading    SAT_Math  \
# count      161     161.000000  161.000000   161.000000  161.000000
# unique      57            NaN         NaN          NaN         NaN
# top     Gifted            NaN         NaN          NaN         NaN
# freq        23            NaN         NaN          NaN         NaN
# mean       NaN   93505.913043   10.664596   574.173913  554.906832
# std        NaN   66533.835069    3.771512    71.036132   77.375206
# min        NaN    2901.000000    1.000000   365.000000  385.000000
# 25%        NaN   39905.000000    9.000000   523.000000  497.000000
# 50%        NaN   61906.000000    9.000000   585.000000  548.000000
# 75%        NaN  137904.000000   12.000000   643.000000  630.000000
# max        NaN  252901.000000   20.000000   690.000000  755.000000
#
#               Total  Above_Crit_Rate  Above_TSI_Both_Rate     English  \
# count    161.000000       161.000000           161.000000  161.000000
# unique          NaN              NaN                  NaN         NaN
# top             NaN              NaN                  NaN         NaN
# freq            NaN              NaN                  NaN         NaN
# mean    1129.086957        94.731056            95.041615   23.819876
# std      145.117814        17.345314            16.983255    5.430548
# min      750.000000        20.000000            20.000000   11.000000
# 25%     1026.000000       100.000000           100.000000   19.300000
# 50%     1110.000000       100.000000           100.000000   23.300000
# 75%     1273.000000       100.000000           100.000000   30.000000
# max     1420.000000       100.000000           100.000000   30.500000
#
#           ACT_Math     Reading     Science      Compos
# count   161.000000  161.000000  161.000000  161.000000
# unique         NaN         NaN         NaN         NaN
# top            NaN         NaN         NaN         NaN
# freq           NaN         NaN         NaN         NaN
# mean     23.398137   26.223602   24.393789   24.523602
# std       4.144250    5.374704    4.104018    4.610877
# min      13.300000   15.300000   14.300000   13.700000
# 25%      19.900000   21.800000   21.000000   20.600000
# 50%      22.300000   25.800000   23.500000   23.800000
# 75%      28.000000   32.000000   29.000000   29.700000
# max      31.000000   34.000000   34.000000   32.000000

# %%
sns.set(style='darkgrid')
plt.figure(figsize=(20,10))
ax = sns.countplot(x='Group', data=d)

# %% [markdown]
# # Descriptive Stats of Campus Level

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
print(c.shape)
print(c.info())
# Out:
# (225, 14)
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 225 entries, 0 to 224
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Group                225 non-null    object
#  1   Campus               225 non-null    int64
#  2   District             225 non-null    int64
#  3   Region               225 non-null    int64
#  4   SAT_Reading          225 non-null    float64
#  5   SAT_Math             225 non-null    float64
#  6   Total                225 non-null    float64
#  7   Above_Crit_Rate      225 non-null    float64
#  8   Above_TSI_Both_Rate  225 non-null    float64
#  9   English              225 non-null    float64
#  10  ACT_Math             225 non-null    float64
#  11  Reading              225 non-null    float64
#  12  Science              225 non-null    float64
#  13  Compos               225 non-null    float64
# dtypes: float64(10), int64(3), object(1)
# memory usage: 26.4+ KB
# None

# %%
import pandas as pd
c['Compos'] = pd.to_numeric(c['Compos'], errors='coerce')
c['Total'] = pd.to_numeric(c['Total'], errors='coerce')
c['English'] = pd.to_numeric(c['English'], errors='coerce')
c['SAT_Math'] = pd.to_numeric(c['SAT_Math'], errors='coerce')
c['Above_Crit_Rate'] = pd.to_numeric(c['Above_Crit_Rate'], errors='coerce')
c['Above_TSI_Both_Rate'] = pd.to_numeric(c['Above_TSI_Both_Rate'], errors='coerce')
c['ACT_Math'] = pd.to_numeric(c['ACT_Math'], errors='coerce')
c['Reading'] = pd.to_numeric(c['Reading'], errors='coerce')
c['Science'] = pd.to_numeric(c['Science'], errors='coerce')
print(c.dtypes)
# Out:
# Group                   object
# Campus                   int64
# District                 int64
# Region                   int64
# SAT_Reading            float64
# SAT_Math               float64
# Total                  float64
# Above_Crit_Rate        float64
# Above_TSI_Both_Rate    float64
# English                float64
# ACT_Math               float64
# Reading                float64
# Science                float64
# Compos                 float64
# dtype: object

# %%
c.describe(include='all')
# Out:
#          Group        Campus       District      Region  SAT_Reading  \
# count      225  2.250000e+02     225.000000  225.000000   225.000000
# unique      57           NaN            NaN         NaN          NaN
# top     Gifted           NaN            NaN         NaN          NaN
# freq        26           NaN            NaN         NaN          NaN
# mean       NaN  9.541051e+07   95410.497778   10.266667   572.751111
# std        NaN  6.967071e+07   69670.711863    4.431019    71.647826
# min        NaN  2.901001e+06    2901.000000    1.000000   365.000000
# 25%        NaN  3.990500e+07   39905.000000    9.000000   520.000000
# 50%        NaN  6.190500e+07   61905.000000   10.000000   581.000000
# 75%        NaN  1.379040e+08  137904.000000   12.000000   643.000000
# max        NaN  2.529010e+08  252901.000000   20.000000   703.000000
#
#           SAT_Math        Total  Above_Crit_Rate  Above_TSI_Both_Rate  \
# count   225.000000   225.000000       225.000000           225.000000
# unique         NaN          NaN              NaN                  NaN
# top            NaN          NaN              NaN                  NaN
# freq           NaN          NaN              NaN                  NaN
# mean    556.995556  1129.706667        94.785333            95.452000
# std      76.551424   145.321574        16.983955            15.997804
# min     385.000000   750.000000        20.000000            20.000000
# 25%     497.000000  1026.000000       100.000000           100.000000
# 50%     552.000000  1121.000000       100.000000           100.000000
# 75%     630.000000  1273.000000       100.000000           100.000000
# max     755.000000  1420.000000       100.000000           100.000000
#
#            English    ACT_Math     Reading     Science      Compos
# count   225.000000  225.000000  225.000000  225.000000  225.000000
# unique         NaN         NaN         NaN         NaN         NaN
# top            NaN         NaN         NaN         NaN         NaN
# freq           NaN         NaN         NaN         NaN         NaN
# mean     23.517333   23.254667   25.657778   24.155556   24.211556
# std       5.436058    4.123776    5.329278    4.163723    4.618958
# min      11.000000   13.300000   15.100000   12.500000   13.500000
# 25%      19.300000   19.900000   21.700000   20.900000   20.600000
# 50%      22.800000   22.400000   25.600000   23.600000   23.800000
# 75%      30.000000   28.000000   32.000000   29.000000   29.700000
# max      33.000000   31.100000   34.500000   34.000000   32.100000

# %%
sns.set(style='darkgrid')
plt.figure(figsize=(20,10))
ax = sns.countplot(x='Group', data=c)

# %% [markdown]
# ## Checking the Min/Max values in SAT/ACT District Level

# %%
print(d.min())
# Out:
# Group                  African American
# District                           2901
# Region                                1
# SAT_Reading                       365.0
# SAT_Math                          385.0
# Total                             750.0
# Above_Crit_Rate                    20.0
# Above_TSI_Both_Rate                20.0
# English                            11.0
# ACT_Math                           13.3
# Reading                            15.3
# Science                            14.3
# Compos                             13.7
# dtype: object

# %%
print(d.max())
# Out:
# Group                   White
# District               252901
# Region                     20
# SAT_Reading             690.0
# SAT_Math                755.0
# Total                  1420.0
# Above_Crit_Rate         100.0
# Above_TSI_Both_Rate     100.0
# English                  30.5
# ACT_Math                 31.0
# Reading                  34.0
# Science                  34.0
# Compos                   32.0
# dtype: object

# %% [markdown]
# ## Checking the Min/Max in SAT/ACT in Campus Level

# %%
print(c.min())
# Out:
# Group                  African American
# Campus                          2901001
# District                           2901
# Region                                1
# SAT_Reading                       365.0
# SAT_Math                          385.0
# Total                             750.0
# Above_Crit_Rate                    20.0
# Above_TSI_Both_Rate                20.0
# English                            11.0
# ACT_Math                           13.3
# Reading                            15.1
# Science                            12.5
# Compos                             13.5
# dtype: object

# %%
print(c.max())
# Out:
# Group                      White
# Campus                 252901001
# District                  252901
# Region                        20
# SAT_Reading                703.0
# SAT_Math                   755.0
# Total                     1420.0
# Above_Crit_Rate            100.0
# Above_TSI_Both_Rate        100.0
# English                     33.0
# ACT_Math                    31.1
# Reading                     34.5
# Science                     34.0
# Compos                      32.1
# dtype: object

# %% [markdown]
# ## Standard Deviation

# %%
import pandas as pd 
c.mean(axis=0)
c.std(axis=0)
# Out:
# C:\Users\Sophi\AppData\Local\Temp\ipykernel_21856\1142678162.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   c.mean(axis=0)
# C:\Users\Sophi\AppData\Local\Temp\ipykernel_21856\1142678162.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   c.std(axis=0)
# Campus                 6.967071e+07
# District               6.967071e+04
# Region                 4.431019e+00
# SAT_Reading            7.164783e+01
# SAT_Math               7.655142e+01
# Total                  1.453216e+02
# Above_Crit_Rate        1.698396e+01
# Above_TSI_Both_Rate    1.599780e+01
# English                5.436058e+00
# ACT_Math               4.123776e+00
# Reading                5.329278e+00
# Science                4.163723e+00
# Compos                 4.618958e+00
# dtype: float64

# %%
d.mean(axis=0)
d.std(axis=0)
# Out:
# District               0.460464
# Region                 0.410260
# SAT_Reading            0.529590
# SAT_Math               0.530669
# Total                  0.541343
# Above_Crit_Rate        0.372925
# Above_TSI_Both_Rate    0.373717
# English                0.568987
# ACT_Math               0.560591
# Reading                0.561457
# Science                0.555412
# Compos                 0.569712
# dtype: float64

# %% [markdown]
# # Checking the Correlation of the variables

# %%
d=d.corr()
print(d)
# Out:
#                      District    Region  SAT_Reading  SAT_Math     Total  \
# District             1.000000  0.977270    -0.976175 -0.985010 -0.981094
# Region               0.977270  1.000000    -0.965970 -0.975921 -0.971480
# SAT_Reading         -0.976175 -0.965970     1.000000  0.998743  0.999657
# SAT_Math            -0.985010 -0.975921     0.998743  1.000000  0.999713
# Total               -0.981094 -0.971480     0.999657  0.999713  1.000000
# Above_Crit_Rate     -0.317881 -0.349834     0.126381  0.175863  0.152281
# Above_TSI_Both_Rate -0.344215 -0.376676     0.154582  0.203815  0.180360
# English             -0.988015 -0.976904     0.997701  0.999676  0.999046
# ACT_Math            -0.986290 -0.975664     0.998379  0.999833  0.999452
# Reading             -0.986808 -0.975337     0.998212  0.999744  0.999325
# Science             -0.987948 -0.977561     0.997642  0.999681  0.999020
# Compos              -0.987057 -0.976033     0.998098  0.999760  0.999279
#
#                      Above_Crit_Rate  Above_TSI_Both_Rate   English  ACT_Math  \
# District                   -0.317881            -0.344215 -0.988015 -0.986290
# Region                     -0.349834            -0.376676 -0.976904 -0.975664
# SAT_Reading                 0.126381             0.154582  0.997701  0.998379
# SAT_Math                    0.175863             0.203815  0.999676  0.999833
# Total                       0.152281             0.180360  0.999046  0.999452
# Above_Crit_Rate             1.000000             0.999584  0.189365  0.179332
# Above_TSI_Both_Rate         0.999584             1.000000  0.217178  0.207224
# English                     0.189365             0.217178  1.000000  0.999938
# ACT_Math                    0.179332             0.207224  0.999938  1.000000
# Reading                     0.180626             0.208488  0.999960  0.999987
# Science                     0.190775             0.218596  0.999994  0.999930
# Compos                      0.183270             0.211127  0.999980  0.999987
#
#                       Reading   Science    Compos
# District            -0.986808 -0.987948 -0.987057
# Region              -0.975337 -0.977561 -0.976033
# SAT_Reading          0.998212  0.997642  0.998098
# SAT_Math             0.999744  0.999681  0.999760
# Total                0.999325  0.999020  0.999279
# Above_Crit_Rate      0.180626  0.190775  0.183270
# Above_TSI_Both_Rate  0.208488  0.218596  0.211127
# English              0.999960  0.999994  0.999980
# ACT_Math             0.999987  0.999930  0.999987
# Reading              1.000000  0.999941  0.999995
# Science              0.999941  1.000000  0.999969
# Compos               0.999995  0.999969  1.000000

# %%
import seaborn as sns

#Heat map of SAT/ACT District Texas 
plt.figure(figsize=(9,5))
sns.heatmap(d.corr(), annot =True)
# Out:
# <AxesSubplot:>

# %%
c=c.corr()
print(c)
# Out:
#                        Campus  District    Region  SAT_Reading  SAT_Math  \
# Campus               1.000000  1.000000  0.055332    -0.332445 -0.388457
# District             1.000000  1.000000  0.055332    -0.332445 -0.388457
# Region               0.055332  0.055332  1.000000    -0.165187 -0.201376
# SAT_Reading         -0.332445 -0.332445 -0.165187     1.000000  0.922611
# SAT_Math            -0.388457 -0.388457 -0.201376     0.922611  1.000000
# Total               -0.368455 -0.368455 -0.187733     0.979166  0.981711
# Above_Crit_Rate     -0.202369 -0.202369 -0.051889     0.099596  0.177757
# Above_TSI_Both_Rate -0.226361 -0.226361 -0.063905     0.121266  0.197648
# English             -0.438692 -0.438692 -0.191443     0.857430  0.834824
# ACT_Math            -0.418441 -0.418441 -0.198478     0.867368  0.875805
# Reading             -0.405456 -0.405456 -0.202562     0.838134  0.814037
# Science             -0.392011 -0.392011 -0.187803     0.846688  0.847421
# Compos              -0.417446 -0.417446 -0.196507     0.868937  0.855988
#
#                         Total  Above_Crit_Rate  Above_TSI_Both_Rate   English  \
# Campus              -0.368455        -0.202369            -0.226361 -0.438692
# District            -0.368455        -0.202369            -0.226361 -0.438692
# Region              -0.187733        -0.051889            -0.063905 -0.191443
# SAT_Reading          0.979166         0.099596             0.121266  0.857430
# SAT_Math             0.981711         0.177757             0.197648  0.834824
# Total                1.000000         0.142717             0.163888  0.862650
# Above_Crit_Rate      0.142717         1.000000             0.951266  0.183889
# Above_TSI_Both_Rate  0.163888         0.951266             1.000000  0.193294
# English              0.862650         0.183889             0.193294  1.000000
# ACT_Math             0.889160         0.167951             0.185869  0.949522
# Reading              0.842257         0.144869             0.158581  0.961618
# Science              0.864064         0.166986             0.193476  0.945209
# Compos               0.879518         0.166149             0.182026  0.984815
#
#                      ACT_Math   Reading   Science    Compos
# Campus              -0.418441 -0.405456 -0.392011 -0.417446
# District            -0.418441 -0.405456 -0.392011 -0.417446
# Region              -0.198478 -0.202562 -0.187803 -0.196507
# SAT_Reading          0.867368  0.838134  0.846688  0.868937
# SAT_Math             0.875805  0.814037  0.847421  0.855988
# Total                0.889160  0.842257  0.864064  0.879518
# Above_Crit_Rate      0.167951  0.144869  0.166986  0.166149
# Above_TSI_Both_Rate  0.185869  0.158581  0.193476  0.182026
# English              0.949522  0.961618  0.945209  0.984815
# ACT_Math             1.000000  0.935831  0.970617  0.978922
# Reading              0.935831  1.000000  0.935209  0.979695
# Science              0.970617  0.935209  1.000000  0.978455
# Compos               0.978922  0.979695  0.978455  1.000000

# %%
import seaborn as sns

#Heat map of SAT/ACT Campus Texas 
plt.figure(figsize=(9,5))
sns.heatmap(c.corr(), annot =True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Find Pairplots for Campus and Distrisct

# %%
sns.pairplot(c)

# %%
sns.pairplot(d)

# %% [markdown]
# # Visualize Graph

# %%
c.head()
# Out:
#                Group    Campus  District  Region  SAT_Reading  SAT_Math  \
# 0              Asian   2901001      2901      18        525.0     516.0
# 1        Multiracial  13901001     13901       2        580.0     530.0
# 2  Missing Ethnicity  13901001     13901       2        580.0     530.0
# 3              Asian  14908001     14908      12        583.0     559.0
# 4    American Indian  15907023     15907      20        588.0     573.0
#
#     Total  Above_Crit_Rate  Above_TSI_Both_Rate  English  ACT_Math  Reading  \
# 0  1041.0            100.0                100.0     20.8      21.6     23.5
# 1  1110.0             33.3                 33.3     25.0      21.7     25.7
# 2  1110.0             33.3                 33.3     25.0      21.7     25.7
# 3  1142.0            100.0                100.0     22.8      25.2     25.7
# 4  1161.0            100.0                100.0     24.3      24.1     25.2
#
#    Science  Compos
# 0     22.7    22.3
# 1     21.0    23.3
# 2     21.0    23.3
# 3     25.6    25.0
# 4     23.7    24.3

# %%
d.head()
# Out:
#                Group  District  Region  SAT_Reading  SAT_Math   Total  \
# 0              Asian      2901      18        525.0     516.0  1041.0
# 1        Multiracial     13901       2        580.0     530.0  1110.0
# 2  Missing Ethnicity     13901       2        580.0     530.0  1110.0
# 3              Asian     14908      12        583.0     559.0  1142.0
# 4        Multiracial     17901      17        626.0     563.0  1189.0
#
#    Above_Crit_Rate  Above_TSI_Both_Rate  English  ACT_Math  Reading  Science  \
# 0            100.0                100.0     20.8      21.6     23.5     22.7
# 1             33.3                 33.3     25.0      21.7     25.7     21.0
# 2             33.3                 33.3     25.0      21.7     25.7     21.0
# 3            100.0                100.0     22.8      25.2     25.7     25.6
# 4            100.0                100.0     22.8      22.4     25.6     23.9
#
#    Compos
# 0    22.3
# 1    23.3
# 2    23.3
# 3    25.0
# 4    23.8

# %%
import matplotlib.pyplot as plt
import pandas as pd
c =  pd.read_csv('c.csv')
group_data = c["Group"]
SAT_data = c["SAT_Math"]
colors = ["#1f77b4", "#ff7f0e", "#2ca02c", "#d62728", "#8c564b"]
explode = (0.1, 0, 0, 0, 0)  
plt.pie(SAT_data, labels=group_data, explode=None, colors=colors,
autopct='%1.1f%%', shadow=True, startangle=140)
plt.title("SAT Math\n"+"groups of students in Campus Level ")
plt.show()

# %%
d =  pd.read_csv('d.csv')
group_data = d["Group"]
SAT_data = d["SAT_Math"]
colors = ["#1f77b4", "#ff7f0e", "#2ca02c", "#d62728", "#8c564b"]
explode = (0.1, 0, 0, 0, 0)  
plt.pie(SAT_data, labels=group_data, explode=None, colors=colors,
autopct='%1.1f%%', shadow=True, startangle=140)
plt.title("SAT Math\n"+"groups of students in District Level ")
plt.show()

# %% [markdown]
# ## Visualize ACT/SAT Math in District Level

# %%
np.std(d['SAT_Math'][0:50])
# Out:
# 42.23091284829157

# %%
np.median(d['SAT_Math'][0:50])
# Out:
# 630.0

# %%
d.SAT_Math.iloc[0:50].mean()
# Out:
# 610.9

# %%
d.hist(column='SAT_Math', xlabelsize=30, ylabelsize=30, figsize=(20,10), bins=10)[0:50]
plt.xlabel('SAT Math Scores', fontsize=20)
plt.ylabel('Number of Student Particpate in District', fontsize=20)
plt.title('SAT Math Scores Across the District in Texas')
# Out:
# Text(0.5, 1.0, 'SAT Math Scores Across the District in Texas')

# %%
np.std(d['ACT_Math'][0:50])
# Out:
# 2.5045366837002

# %%
np.median(d['ACT_Math'][0:50])
# Out:
# 28.0

# %%
d.ACT_Math.iloc[0:50].mean()
# Out:
# 26.764

# %%
d.hist(column='ACT_Math', xlabelsize=30, ylabelsize=30, figsize=(20,10), bins=10)[0:50]
plt.xlabel('ACT Math Scores', fontsize=20)
plt.ylabel('Number of Stundent Particpate in District Level', fontsize=20)
plt.title('ACT Math Scores Across the District in Texas')
# Out:
# Text(0.5, 1.0, 'ACT Math Scores Across the District in Texas')

# %% [markdown]
# ## Visual SAT/ACT Verbal in District Level

# %%
np.std(d['SAT_Reading'][0:50])
# Out:
# 37.65745078998312

# %%
np.median(d['SAT_Reading'][0:50])
# Out:
# 643.0

# %%
d.SAT_Reading.iloc[0:50].mean()
# Out:
# 626.58

# %%
d.hist(column='SAT_Reading', xlabelsize=30, ylabelsize=30, figsize=(20,10), bins=20)[0:50]
plt.xlabel('ERW SAT Scores', fontsize=20)
plt.ylabel('Number of Stundent Particpate in District Level', fontsize=20)
plt.title('SAT Reading scores Across the Disctrit in Texas')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
np.std(d['Reading'][0:50])
# Out:
# 3.020612520665306

# %%
np.median(d['Reading'][0:50])
# Out:
# 32.0

# %%
d.Reading.iloc[0:50].mean()
# Out:
# 30.71

# %%
d.hist(column='Reading', xlabelsize=30, ylabelsize=30, figsize=(20,10), bins=20)[0:50]
plt.xlabel('Reading ACT Scores', fontsize=20)
plt.ylabel('Number of Stundent Particpate in District Level', fontsize=20)
plt.title('Reading ACT scores Across the Disctrit in Texas')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## Visual ACT/SAT Math in Campus Level

# %%
np.std(c['SAT_Math'][0:50])
# Out:
# 47.72665502630576

# %%
np.median(c['SAT_Math'][0:50])
# Out:
# 625.0

# %%
c.SAT_Math.iloc[0:50].mean()
# Out:
# 596.92

# %%
c.hist(column='SAT_Math', xlabelsize=30, ylabelsize=30, figsize=(20,10), bins=10)[0:50]
plt.xlabel('SAT Math Scores', fontsize=20)
plt.ylabel('Number of Student Particpate in Campus', fontsize=20)
plt.title('SAT Math Scores Across the Campus in Texas')
# Out:
# Text(0.5, 1.0, 'SAT Math Scores Across the Campus in Texas')

# %%
np.std(c['ACT_Math'][0:50])
# Out:
# 2.8935099792466574

# %%
np.median(c['ACT_Math'][0:50])
# Out:
# 28.0

# %%
c.ACT_Math.iloc[0:50].mean()
# Out:
# 25.88

# %%
c.hist(column='ACT_Math', xlabelsize=30, ylabelsize=30, figsize=(20,10), bins=10)[0:50]
plt.xlabel('ACT Math Scores', fontsize=20)
plt.ylabel('Number of Stundent Particpate in Campus Level', fontsize=20)
plt.title('ACT Math Scores Across the Campus in Texas')
# Out:
# Text(0.5, 1.0, 'ACT Math Scores Across the Campus in Texas')

# %% [markdown]
# ## Visual SAT/ACT Verbal in Campus Level

# %%
np.std(c['SAT_Reading'][0:50])
# Out:
# 46.011928888061185

# %%
np.median(c['SAT_Reading'][0:50])
# Out:
# 634.5

# %%
c.SAT_Reading.iloc[0:50].mean()
# Out:
# 610.68

# %%
c.hist(column='SAT_Reading', xlabelsize=30, ylabelsize=30, figsize=(20,10), bins=20)[0:50]
plt.xlabel('ERW SAT Scores', fontsize=20)
plt.ylabel('Number of Stundent Particpate in Campuus Level', fontsize=20)
plt.title('SAT Reading scores Across the Campus in Texas')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
np.std(c['Reading'][0:50])
# Out:
# 3.7205273819715394

# %%
np.median(c['Reading'][0:50])
# Out:
# 30.0

# %%
c.Reading.iloc[0:50].mean()
# Out:
# 29.074

# %%
c.hist(column='Reading', xlabelsize=30, ylabelsize=30, figsize=(20,10), bins=20)[0:50]
plt.xlabel('Reading ACT Scores', fontsize=20)
plt.ylabel('Number of Stundent Particpate in Campus Level', fontsize=20)
plt.title('Reading ACT scores Across the Campus in Texas')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # Finding Relationship in District Level

# %%
np.corrcoef(d['Total'],d['Compos'])
# Out:
# array([[1.        , 0.87426684],
#        [0.87426684, 1.        ]])

# %%
d.plot.scatter('Total', 'Compos')
plt.xlabel('Total SAT Score', fontsize=20)
plt.ylabel('Composite ACT Score', fontsize=20)
plt.title('ACT Composite Scores vs. SAT Total Scores in District Level')
# Out:
# Text(0.5, 1.0, 'ACT Composite Scores vs. SAT Total Scores in District Level')

# %% [markdown]
# # Finding Realtionship in Campus Level

# %%
c =  pd.read_csv('c.csv')

# %%
np.corrcoef(c['Total'],c['Compos'])
# Out:
# array([[1.        , 0.87951819],
#        [0.87951819, 1.        ]])

# %%
c.plot.scatter('Total', 'Compos')
plt.xlabel('Total SAT Score', fontsize=20)
plt.ylabel('Composite ACT Score', fontsize=20)
plt.title('ACT Composite Scores vs. SAT Total Scores Campus Student')
# Out:
# Text(0.5, 1.0, 'ACT Composite Scores vs. SAT Total Scores Campus Student')

# %% [markdown]
# # Choose a color for a map

# %%
import json
import requests
import branca.colormap as cm

# %%
#Choosing Set3_11 as the color for the Texas Map
cm.linear.Set3_11
# Out:
# <svg height="40" width="450"><line x1="0" y1="15" x2="0" y2="27" style="stroke:#8dd3c7ff;stroke-width:2;" /><line x1="1" y1="15" x2="1" y2="27" style="stroke:#90d4c7ff;stroke-width:2;" /><line x1="2" y1="15" x2="2" y2="27" style="stroke:#92d5c6ff;stroke-width:2;" /><line x1="3" y1="15" x2="3" y2="27" style="stroke:#95d6c6ff;stroke-width:2;" /><line x1="4" y1="15" x2="4" y2="27" style="stroke:#97d7c5ff;stroke-width:2;" /><line x1="5" y1="15" x2="5" y2="27" style="stroke:#9ad8c5ff;stroke-width:2;" /><line x1="6" y1="15" x2="6" y2="27" style="stroke:#9cd9c5ff;stroke-width:2;" /><line x1="7" y1="15" x2="7" y2="27" style="stroke:#9fdac4ff;stroke-width:2;" /><line x1="8" y1="15" x2="8" y2="27" style="stroke:#a1dbc4ff;stroke-width:2;" /><line x1="9" y1="15" x2="9" y2="27" style="stroke:#a4dcc3ff;stroke-width:2;" /><line x1="10" y1="15" x2="10" y2="27" style="stroke:#a7ddc3ff;stroke-width:2;" /><line x1="11" y1="15" x2="11" y2="27" style="stroke:#a9dec2ff;stroke-width:2;" /><line x1="12" y1="15" x2="12" y2="27" style="stroke:#acdfc2ff;stroke-width:2;" /><line x1="13" y1="15" x2="13" y2="27" style="stroke:#aee0c1ff;stroke-width:2;" /><line x1="14" y1="15" x2="14" y2="27" style="stroke:#b1e1c1ff;stroke-width:2;" /><line x1="15" y1="15" x2="15" y2="27" style="stroke:#b3e2c1ff;stroke-width:2;" /><line x1="16" y1="15" x2="16" y2="27" style="stroke:#b6e3c0ff;stroke-width:2;" /><line x1="17" y1="15" x2="17" y2="27" style="stroke:#b8e4c0ff;stroke-width:2;" /><line x1="18" y1="15" x2="18" y2="27" style="stroke:#bbe5bfff;stroke-width:2;" /><line x1="19" y1="15" x2="19" y2="27" style="stroke:#bde6bfff;stroke-width:2;" /><line x1="20" y1="15" x2="20" y2="27" style="stroke:#c0e7beff;stroke-width:2;" /><line x1="21" y1="15" x2="21" y2="27" style="stroke:#c3e8beff;stroke-width:2;" /><line x1="22" y1="15" x2="22" y2="27" style="stroke:#c5e9bdff;stroke-width:2;" /><line x1="23" y1="15" x2="23" y2="27" style="stroke:#c8eabdff;stroke-width:2;" /><line x1="24" y1="15" x2="24" y2="27" style="stroke:#caebbdff;stroke-width:2;" /><line x1="25" y1="15" x2="25" y2="27" style="stroke:#cdecbcff;stroke-width:2;" /><line x1="26" y1="15" x2="26" y2="27" style="stroke:#cfedbcff;stroke-width:2;" /><line x1="27" y1="15" x2="27" y2="27" style="stroke:#d2eebbff;stroke-width:2;" /><line x1="28" y1="15" x2="28" y2="27" style="stroke:#d4efbbff;stroke-width:2;" /><line x1="29" y1="15" x2="29" y2="27" style="stroke:#d7f0baff;stroke-width:2;" /><line x1="30" y1="15" x2="30" y2="27" style="stroke:#daf1baff;stroke-width:2;" /><line x1="31" y1="15" x2="31" y2="27" style="stroke:#dcf2b9ff;stroke-width:2;" /><line x1="32" y1="15" x2="32" y2="27" style="stroke:#dff3b9ff;stroke-width:2;" /><line x1="33" y1="15" x2="33" y2="27" style="stroke:#e1f4b9ff;stroke-width:2;" /><line x1="34" y1="15" x2="34" y2="27" style="stroke:#e4f5b8ff;stroke-width:2;" /><line x1="35" y1="15" x2="35" y2="27" style="stroke:#e6f6b8ff;stroke-width:2;" /><line x1="36" y1="15" x2="36" y2="27" style="stroke:#e9f7b7ff;stroke-width:2;" /><line x1="37" y1="15" x2="37" y2="27" style="stroke:#ebf8b7ff;stroke-width:2;" /><line x1="38" y1="15" x2="38" y2="27" style="stroke:#eef9b6ff;stroke-width:2;" /><line x1="39" y1="15" x2="39" y2="27" style="stroke:#f0fab6ff;stroke-width:2;" /><line x1="40" y1="15" x2="40" y2="27" style="stroke:#f3fbb5ff;stroke-width:2;" /><line x1="41" y1="15" x2="41" y2="27" style="stroke:#f6fcb5ff;stroke-width:2;" /><line x1="42" y1="15" x2="42" y2="27" style="stroke:#f8fdb4ff;stroke-width:2;" /><line x1="43" y1="15" x2="43" y2="27" style="stroke:#fbfeb4ff;stroke-width:2;" /><line x1="44" y1="15" x2="44" y2="27" style="stroke:#fdffb4ff;stroke-width:2;" /><line x1="45" y1="15" x2="45" y2="27" style="stroke:#ffffb3ff;stroke-width:2;" /><line x1="46" y1="15" x2="46" y2="27" style="stroke:#fefeb4ff;stroke-width:2;" /><line x1="47" y1="15" x2="47" y2="27" style="stroke:#fcfcb5ff;stroke-width:2;" /><line x1="48" y1="15" x2="48" y2="27" style="stroke:#fbfbb6ff;stroke-width:2;" /><line x1="49" y1="15"  ...

# %%
cm.linear.Pastel2_08
# Out:
# <svg height="40" width="450"><line x1="0" y1="15" x2="0" y2="27" style="stroke:#b3e2cdff;stroke-width:2;" /><line x1="1" y1="15" x2="1" y2="27" style="stroke:#b4e2cdff;stroke-width:2;" /><line x1="2" y1="15" x2="2" y2="27" style="stroke:#b6e2ccff;stroke-width:2;" /><line x1="3" y1="15" x2="3" y2="27" style="stroke:#b7e1ccff;stroke-width:2;" /><line x1="4" y1="15" x2="4" y2="27" style="stroke:#b8e1cbff;stroke-width:2;" /><line x1="5" y1="15" x2="5" y2="27" style="stroke:#b9e1cbff;stroke-width:2;" /><line x1="6" y1="15" x2="6" y2="27" style="stroke:#bae0caff;stroke-width:2;" /><line x1="7" y1="15" x2="7" y2="27" style="stroke:#bbe0caff;stroke-width:2;" /><line x1="8" y1="15" x2="8" y2="27" style="stroke:#bce0c9ff;stroke-width:2;" /><line x1="9" y1="15" x2="9" y2="27" style="stroke:#bedfc9ff;stroke-width:2;" /><line x1="10" y1="15" x2="10" y2="27" style="stroke:#bfdfc8ff;stroke-width:2;" /><line x1="11" y1="15" x2="11" y2="27" style="stroke:#c0dfc8ff;stroke-width:2;" /><line x1="12" y1="15" x2="12" y2="27" style="stroke:#c1dec7ff;stroke-width:2;" /><line x1="13" y1="15" x2="13" y2="27" style="stroke:#c2dec7ff;stroke-width:2;" /><line x1="14" y1="15" x2="14" y2="27" style="stroke:#c3dec6ff;stroke-width:2;" /><line x1="15" y1="15" x2="15" y2="27" style="stroke:#c5ddc6ff;stroke-width:2;" /><line x1="16" y1="15" x2="16" y2="27" style="stroke:#c6ddc5ff;stroke-width:2;" /><line x1="17" y1="15" x2="17" y2="27" style="stroke:#c7ddc5ff;stroke-width:2;" /><line x1="18" y1="15" x2="18" y2="27" style="stroke:#c8dcc4ff;stroke-width:2;" /><line x1="19" y1="15" x2="19" y2="27" style="stroke:#c9dcc3ff;stroke-width:2;" /><line x1="20" y1="15" x2="20" y2="27" style="stroke:#cadcc3ff;stroke-width:2;" /><line x1="21" y1="15" x2="21" y2="27" style="stroke:#ccdbc2ff;stroke-width:2;" /><line x1="22" y1="15" x2="22" y2="27" style="stroke:#cddbc2ff;stroke-width:2;" /><line x1="23" y1="15" x2="23" y2="27" style="stroke:#cedbc1ff;stroke-width:2;" /><line x1="24" y1="15" x2="24" y2="27" style="stroke:#cfdac1ff;stroke-width:2;" /><line x1="25" y1="15" x2="25" y2="27" style="stroke:#d0dac0ff;stroke-width:2;" /><line x1="26" y1="15" x2="26" y2="27" style="stroke:#d1dac0ff;stroke-width:2;" /><line x1="27" y1="15" x2="27" y2="27" style="stroke:#d2dabfff;stroke-width:2;" /><line x1="28" y1="15" x2="28" y2="27" style="stroke:#d4d9bfff;stroke-width:2;" /><line x1="29" y1="15" x2="29" y2="27" style="stroke:#d5d9beff;stroke-width:2;" /><line x1="30" y1="15" x2="30" y2="27" style="stroke:#d6d9beff;stroke-width:2;" /><line x1="31" y1="15" x2="31" y2="27" style="stroke:#d7d8bdff;stroke-width:2;" /><line x1="32" y1="15" x2="32" y2="27" style="stroke:#d8d8bdff;stroke-width:2;" /><line x1="33" y1="15" x2="33" y2="27" style="stroke:#d9d8bcff;stroke-width:2;" /><line x1="34" y1="15" x2="34" y2="27" style="stroke:#dbd7bcff;stroke-width:2;" /><line x1="35" y1="15" x2="35" y2="27" style="stroke:#dcd7bbff;stroke-width:2;" /><line x1="36" y1="15" x2="36" y2="27" style="stroke:#ddd7bbff;stroke-width:2;" /><line x1="37" y1="15" x2="37" y2="27" style="stroke:#ded6baff;stroke-width:2;" /><line x1="38" y1="15" x2="38" y2="27" style="stroke:#dfd6baff;stroke-width:2;" /><line x1="39" y1="15" x2="39" y2="27" style="stroke:#e0d6b9ff;stroke-width:2;" /><line x1="40" y1="15" x2="40" y2="27" style="stroke:#e2d5b9ff;stroke-width:2;" /><line x1="41" y1="15" x2="41" y2="27" style="stroke:#e3d5b8ff;stroke-width:2;" /><line x1="42" y1="15" x2="42" y2="27" style="stroke:#e4d5b8ff;stroke-width:2;" /><line x1="43" y1="15" x2="43" y2="27" style="stroke:#e5d4b7ff;stroke-width:2;" /><line x1="44" y1="15" x2="44" y2="27" style="stroke:#e6d4b7ff;stroke-width:2;" /><line x1="45" y1="15" x2="45" y2="27" style="stroke:#e7d4b6ff;stroke-width:2;" /><line x1="46" y1="15" x2="46" y2="27" style="stroke:#e8d3b6ff;stroke-width:2;" /><line x1="47" y1="15" x2="47" y2="27" style="stroke:#ead3b5ff;stroke-width:2;" /><line x1="48" y1="15" x2="48" y2="27" style="stroke:#ebd3b5ff;stroke-width:2;" /><line x1="49" y1="15"  ...

# %% [markdown]
# # Map of Texas

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import folium
from folium import plugins
import json
from folium.plugins import MarkerCluster
from branca.colormap import linear
import branca.colormap as cm
import ipyleaflet
from urllib.request import urlopen
import requests
import plotly.express as px

# %%
d=pd.read_csv('d.csv')
d.head()
# Out:
#                Group  District  Region  SAT_Reading  SAT_Math   Total  \
# 0              Asian      2901      18        525.0     516.0  1041.0
# 1        Multiracial     13901       2        580.0     530.0  1110.0
# 2  Missing Ethnicity     13901       2        580.0     530.0  1110.0
# 3              Asian     14908      12        583.0     559.0  1142.0
# 4        Multiracial     17901      17        626.0     563.0  1189.0
#
#    Above_Crit_Rate  Above_TSI_Both_Rate  English  ACT_Math  Reading  Science  \
# 0            100.0                100.0     20.8      21.6     23.5     22.7
# 1             33.3                 33.3     25.0      21.7     25.7     21.0
# 2             33.3                 33.3     25.0      21.7     25.7     21.0
# 3            100.0                100.0     22.8      25.2     25.7     25.6
# 4            100.0                100.0     22.8      22.4     25.6     23.9
#
#    Compos
# 0    22.3
# 1    23.3
# 2    23.3
# 3    25.0
# 4    23.8

# %%
print(d.shape)
print(d.info())
# Out:
# (161, 13)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 161 entries, 0 to 160
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Group                161 non-null    object
#  1   District             161 non-null    int64
#  2   Region               161 non-null    int64
#  3   SAT_Reading          161 non-null    float64
#  4   SAT_Math             161 non-null    float64
#  5   Total                161 non-null    float64
#  6   Above_Crit_Rate      161 non-null    float64
#  7   Above_TSI_Both_Rate  161 non-null    float64
#  8   English              161 non-null    float64
#  9   ACT_Math             161 non-null    float64
#  10  Reading              161 non-null    float64
#  11  Science              161 non-null    float64
#  12  Compos               161 non-null    float64
# dtypes: float64(10), int64(2), object(1)
# memory usage: 16.5+ KB
# None

# %%
url=("https://raw.githubusercontent.com/OpenDataDE/State-zip-code-GeoJSON/master/tx_texas_zip_codes_geo.min.json")
d=d=pd.read_csv('d.csv')
c=c=pd.read_csv('c.csv')

# %%
d.dtypes
# Out:
# Group                   object
# District                 int64
# Region                   int64
# SAT_Reading            float64
# SAT_Math               float64
# Total                  float64
# Above_Crit_Rate        float64
# Above_TSI_Both_Rate    float64
# English                float64
# ACT_Math               float64
# Reading                float64
# Science                float64
# Compos                 float64
# dtype: object

# %%
c.dtypes
# Out:
# Group                   object
# Campus                   int64
# District                 int64
# Region                   int64
# SAT_Reading            float64
# SAT_Math               float64
# Total                  float64
# Above_Crit_Rate        float64
# Above_TSI_Both_Rate    float64
# English                float64
# ACT_Math               float64
# Reading                float64
# Science                float64
# Compos                 float64
# dtype: object

# %%
test = d.loc[d['Group'],d.columns.isin(['District','Group','Region','Total','Compos'])]
test.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [10], in <cell line: 1>()
# ----> 1 test = d.loc[d['Group'],d.columns.isin(['District','Group','Region','Total','Compos'])]
#       2 test.head()
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:961, in _LocationIndexer.__getitem__(self, key)
#     959     if self._is_scalar_access(key):
#     960         return self.obj._get_value(*key, takeable=self._takeable)
# --> 961     return self._getitem_tuple(key)
#     962 else:
#     963     # we by definition only have the 0th axis
#     964     axis = self.axis or 0
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:1149, in _LocIndexer._getitem_tuple(self, tup)
#    1146 if self._multi_take_opportunity(tup):
#    1147     return self._multi_take(tup)
# -> 1149 return self._getitem_tuple_same_dim(tup)
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:827, in _LocationIndexer._getitem_tuple_same_dim(self, tup)
#     824 if com.is_null_slice(key):
#     825     continue
# --> 827 retval = getattr(retval, self.name)._getitem_axis(key, axis=i)
#     828 # We should never have retval.ndim < self.ndim, as that should
#     829 #  be handled by the _getitem_lowerdim call above.
#     830 assert retval.ndim == self.ndim
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:1191, in _LocIndexer._getitem_axis(self, key, axis)
#    1188     if hasattr(key, "ndim") and key.ndim > 1:
#    1189         raise ValueError("Cannot index with multidimensional key")
# -> 1191     return self._getitem_iterable(key, axis=axis)
#    1193 # nested tuple slicing
#    1194 if is_nested_tuple(key, labels):
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:1132, in _LocIndexer._getitem_iterable(self, key, axis)
#    1129 self._validate_key(key, axis)
#    1131 # A collection of keys
# -> 1132 keyarr, indexer = self._get_listlike_indexer(key, axis)
#    1133 return self.obj._reindex_with_indexers(
#    1134     {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#    1135 )
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:1327, in _LocIndexer._get_listlike_indexer(self, key, axis)
#    1324 ax = self.obj._get_axis(axis)
#    1325 axis_name = self.obj._get_axis_name(axis)
# -> 1327 keyarr, indexer = ax._get_indexer_strict(key, axis_name)
#    1329 return keyarr, indexer
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:5782, in Index._get_indexer_strict(self, key, axis_name)
#    5779 else:
#    5780     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5782 self._raise_if_missing(keyarr, indexer, axis_name)
#    5784 keyarr = self.take(indexer)
#    5785 if isinstance(key, Index):
#    5786     # GH 42790 - Preserve name from an Index
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:5842, in Index._raise_if_missing(self, key, indexer, axis_name)
#    5840     if use_interval_msg:
#    5841         key = list(key)
# -> 5842     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    5844 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    5845 raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['Asian', 'Multiracial', 'Missing Ethnicity', 'Asian', 'Multiracial',\n       'Missing Ethnicity', 'Asian', 'Multiracial', 'Gifted', 'All Students',\n       ...\n       'Multiracial', 'Missing Ethnicity', 'Not Economically Disadvantaged',\n       'Gifted', 'Gifted', 'American Indian', 'Gifted', 'African American',\n       'American Indian', 'Asian'],\n      dtype='object', length=161)] are in the [index]"

# %%
testing = c.loc[c['Group'] == 'Special Ed',c.columns.isin(['District','Group','Region','Total','Compos'])]
testing.head()
# Out:
#           Group  District  Region   Total  Compos
# 49   Special Ed     39905       9  1273.0    29.7
# 114  Special Ed     61910      11  1110.0    24.0
# 179  Special Ed    167904      12  1045.0    20.3
# 205  Special Ed    221801      14   993.0    20.8
# 220  Special Ed    236902       6   965.0    22.9

# %%
test = d.loc[d['Group'] == 'Special Ed',d.columns.isin(['District','Group','Region','Total','Compos'])]
test.head()
# Out:
#           Group  District  Region   Total  Compos
# 36   Special Ed     39905       9  1273.0    29.7
# 81   Special Ed     61910      11  1110.0    24.0
# 131  Special Ed    167904      12  1045.0    20.3

# %%
tests = c.loc[c['Group'] == 'Special Ed',c.columns.isin(['District','Group','Region','Total','Compos'])]
tests.head()
# Out:
#           Group  District  Region   Total  Compos
# 49   Special Ed     39905       9  1273.0    29.7
# 114  Special Ed     61910      11  1110.0    24.0
# 179  Special Ed    167904      12  1045.0    20.3
# 205  Special Ed    221801      14   993.0    20.8
# 220  Special Ed    236902       6   965.0    22.9

# %%
testad = d.loc[d['Group'] == 'Special Ed',d.columns.isin(['District','Group','Region','Total','Compos','Above_Crit_Rate','Above_TSI_Both_Rate'])]
testad.head()
# Out:
#           Group  District  Region   Total  Above_Crit_Rate  \
# 36   Special Ed     39905       9  1273.0            100.0
# 81   Special Ed     61910      11  1110.0             50.0
# 131  Special Ed    167904      12  1045.0            100.0
#
#      Above_TSI_Both_Rate  Compos
# 36                 100.0    29.7
# 81                  50.0    24.0
# 131                100.0    20.3

# %%
testads = c.loc[c['Group'],c.columns.isin(['District','Group','Region','Total','Compos','Above_Crit_Rate','Above_TSI_Both_Rate'])]
testads.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [12], in <cell line: 1>()
# ----> 1 testads = c.loc[c['Group'],c.columns.isin(['District','Group','Region','Total','Compos','Above_Crit_Rate','Above_TSI_Both_Rate'])]
#       2 testads.head()
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:961, in _LocationIndexer.__getitem__(self, key)
#     959     if self._is_scalar_access(key):
#     960         return self.obj._get_value(*key, takeable=self._takeable)
# --> 961     return self._getitem_tuple(key)
#     962 else:
#     963     # we by definition only have the 0th axis
#     964     axis = self.axis or 0
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:1149, in _LocIndexer._getitem_tuple(self, tup)
#    1146 if self._multi_take_opportunity(tup):
#    1147     return self._multi_take(tup)
# -> 1149 return self._getitem_tuple_same_dim(tup)
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:827, in _LocationIndexer._getitem_tuple_same_dim(self, tup)
#     824 if com.is_null_slice(key):
#     825     continue
# --> 827 retval = getattr(retval, self.name)._getitem_axis(key, axis=i)
#     828 # We should never have retval.ndim < self.ndim, as that should
#     829 #  be handled by the _getitem_lowerdim call above.
#     830 assert retval.ndim == self.ndim
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:1191, in _LocIndexer._getitem_axis(self, key, axis)
#    1188     if hasattr(key, "ndim") and key.ndim > 1:
#    1189         raise ValueError("Cannot index with multidimensional key")
# -> 1191     return self._getitem_iterable(key, axis=axis)
#    1193 # nested tuple slicing
#    1194 if is_nested_tuple(key, labels):
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:1132, in _LocIndexer._getitem_iterable(self, key, axis)
#    1129 self._validate_key(key, axis)
#    1131 # A collection of keys
# -> 1132 keyarr, indexer = self._get_listlike_indexer(key, axis)
#    1133 return self.obj._reindex_with_indexers(
#    1134     {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#    1135 )
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:1327, in _LocIndexer._get_listlike_indexer(self, key, axis)
#    1324 ax = self.obj._get_axis(axis)
#    1325 axis_name = self.obj._get_axis_name(axis)
# -> 1327 keyarr, indexer = ax._get_indexer_strict(key, axis_name)
#    1329 return keyarr, indexer
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:5782, in Index._get_indexer_strict(self, key, axis_name)
#    5779 else:
#    5780     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5782 self._raise_if_missing(keyarr, indexer, axis_name)
#    5784 keyarr = self.take(indexer)
#    5785 if isinstance(key, Index):
#    5786     # GH 42790 - Preserve name from an Index
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:5842, in Index._raise_if_missing(self, key, indexer, axis_name)
#    5840     if use_interval_msg:
#    5841         key = list(key)
# -> 5842     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    5844 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    5845 raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['Asian', 'Multiracial', 'Missing Ethnicity', 'Asian', 'American Indian',\n       'Asian', 'White', 'Multiracial', 'Missing Ethnicity', 'Section 504',\n       ...\n       'American Indian', 'Dyslexia', 'Military-Connected', 'American Indian',\n       'Gifted', 'Special Ed', 'Migrant', 'African American',\n       'American Indian', 'Asian'],\n      dtype='object', length=225)] are in the [index]"

# %%
d_d=pd.read_csv('d.csv')
with urlopen('https://raw.githubusercontent.com/OpenDataDE/State-zip-code-GeoJSON/master/tx_texas_zip_codes_geo.min.json') as response:
    texas = json.load(response)

# %%
with urlopen('https://data-nces.opendata.arcgis.com/datasets/nces::public-school-locations-current-1.geojson?outSR=%7B%22latestWkid%22%3A4269%2C%22wkid%22%3A4269%7D') as response:
    tq = json.load(response)

# %%
d['District'] = d['District'].astype('str')
#center=get_center_latlong(d)

# %%
mp = folium.Map(location=[31,-100],default_zoom_start=15)
mp
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_75c77d461c90bc705e2a8a156ac39027 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_75c77d461c90bc705e2a8a156ac39027&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_75c77d461c90bc705e2a8a156ac39027 = L.map(
#                 &quot;map_75c77d461c90bc705e2a8a156ac39027&quot;,
#                 {
#                     center: [31.0, -100.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     defaultZoomStart: 15,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b4baf6bb614a3e3bb2e8b990b4c7f158 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_75c77d461c90bc705e2a8a156ac39027);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
mp.save(" mp.html ")

# %%
mp = folium.Map([43, -100], zoom_start=4)
folium.GeoJson(tq).add_to(mp)

mp

# %%
mp.save(" mp.html ")

# %%
testad.head()

# %%
testad = testad.dropna(subset=['Group','Total','Compos'])
testad.columns

# %%
mp = folium.Map(location=[31,-100],zoom_start=6,titles='cartodbpositron')

choropleth = folium.Choropleth(
    geo_data = tq,
    name= 'choropleth',
    data = testad,
    columns = {'District', 'Compos','Total',}
    key_on = 'feature.properties',
    fill_color='Set3_11',
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name= 'ACT and SAT total scores in District Level',
    highlight= True
 ).add_to(m)
   
folium.LayerControl(collapsed=True).add_to(mp)
mp
# Out:
#   Input In [99]
#     key_on = 'feature.properties',
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Interactive Dashboard

# %%
pip install cufflinks
# Out:
# Collecting cufflinks
#   Downloading cufflinks-0.17.3.tar.gz (81 kB)
# Requirement already satisfied: numpy>=1.9.2 in c:\users\sophi\anaconda3\lib\site-packages (from cufflinks) (1.21.5)
# Requirement already satisfied: pandas>=0.19.2 in c:\users\sophi\anaconda3\lib\site-packages (from cufflinks) (1.4.2)
# Requirement already satisfied: plotly>=4.1.1 in c:\users\sophi\anaconda3\lib\site-packages (from cufflinks) (5.6.0)
# Requirement already satisfied: six>=1.9.0 in c:\users\sophi\anaconda3\lib\site-packages (from cufflinks) (1.16.0)
# Collecting colorlover>=0.2.1
# Note: you may need to restart the kernel to use updated packages.
#   Downloading colorlover-0.3.0-py3-none-any.whl (8.9 kB)
# Requirement already satisfied: setuptools>=34.4.1 in c:\users\sophi\anaconda3\lib\site-packages (from cufflinks) (61.2.0)
# Requirement already satisfied: ipython>=5.3.0 in c:\users\sophi\anaconda3\lib\site-packages (from cufflinks) (8.2.0)
# Requirement already satisfied: ipywidgets>=7.0.0 in c:\users\sophi\anaconda3\lib\site-packages (from cufflinks) (7.6.5)
# Requirement already satisfied: jedi>=0.16 in c:\users\sophi\anaconda3\lib\site-packages (from ipython>=5.3.0->cufflinks) (0.18.1)
# Requirement already satisfied: traitlets>=5 in c:\users\sophi\anaconda3\lib\site-packages (from ipython>=5.3.0->cufflinks) (5.1.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\sophi\anaconda3\lib\site-packages (from ipython>=5.3.0->cufflinks) (3.0.20)
# Requirement already satisfied: pickleshare in c:\users\sophi\anaconda3\lib\site-packages (from ipython>=5.3.0->cufflinks) (0.7.5)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\sophi\anaconda3\lib\site-packages (from ipython>=5.3.0->cufflinks) (2.11.2)
# Requirement already satisfied: colorama in c:\users\sophi\anaconda3\lib\site-packages (from ipython>=5.3.0->cufflinks) (0.4.4)
# Requirement already satisfied: matplotlib-inline in c:\users\sophi\anaconda3\lib\site-packages (from ipython>=5.3.0->cufflinks) (0.1.2)
# Requirement already satisfied: decorator in c:\users\sophi\anaconda3\lib\site-packages (from ipython>=5.3.0->cufflinks) (5.1.1)
# Requirement already satisfied: stack-data in c:\users\sophi\anaconda3\lib\site-packages (from ipython>=5.3.0->cufflinks) (0.2.0)
# Requirement already satisfied: backcall in c:\users\sophi\anaconda3\lib\site-packages (from ipython>=5.3.0->cufflinks) (0.2.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\sophi\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->cufflinks) (1.0.0)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\sophi\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->cufflinks) (6.9.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\sophi\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->cufflinks) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\sophi\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->cufflinks) (3.5.2)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\sophi\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->cufflinks) (5.3.0)
# Requirement already satisfied: nest-asyncio in c:\users\sophi\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (1.5.5)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in c:\users\sophi\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (1.5.1)
# Requirement already satisfied: tornado<7.0,>=4.2 in c:\users\sophi\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (6.1)
# Requirement already satisfied: jupyter-client<8.0 in c:\users\sophi\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (6.1.12)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\sophi\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=5.3.0->cufflinks) (0.8.3)
# Requirement already satisfied: jupyter-core>=4.6.0 in c:\users\sophi\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (4.9.2)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\sophi\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (2.8.2)
# Requirement already satisfied: pyzmq>=13 in c:\users\sophi\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (22.3.0)
# Requirement already satisfied: pywin32>=1.0 in c:\users\sophi\anaconda3\lib\site-packages (from jupyter-core>=4.6.0->jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (302)
# Requirement already satisfied: fastjsonschema in c:\users\sophi\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->cufflinks) (2.15.1)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\sophi\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->cufflinks) (4.4.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\sophi\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets>=7.0.0->cufflinks) (21.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\sophi\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets>=7.0.0->cufflinks) (0.18.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sophi\anaconda3\lib\site-packages (from pandas>=0.19.2->cufflinks) (2021.3)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\sophi\anaconda3\lib\site-packages (from plotly>=4.1.1->cufflinks) (8.0.1)
# Requirement already satisfied: wcwidth in c:\users\sophi\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.3.0->cufflinks) (0.2.5)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\sophi\anaconda3\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (6.4.8)
# Requirement already satisfied: jinja2 in c:\users\sophi\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (2.11.3)
# Requirement already satisfied: argon2-cffi in c:\users\sophi\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (21.3.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\sophi\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (0.13.1)
# Requirement already satisfied: nbconvert in c:\users\sophi\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (6.4.4)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\sophi\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (1.8.0)
# Requirement already satisfied: prometheus-client in c:\users\sophi\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (0.13.1)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\sophi\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (2.0.2)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\sophi\anaconda3\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\sophi\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (1.15.0)
# Requirement already satisfied: pycparser in c:\users\sophi\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (2.21)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\sophi\anaconda3\lib\site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (2.0.1)
# Requirement already satisfied: bleach in c:\users\sophi\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (4.1.0)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\sophi\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (0.4)
# Requirement already satisfied: beautifulsoup4 in c:\users\sophi\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (4.11.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\sophi\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (0.1.2)
# Requirement already satisfied: defusedxml in c:\users\sophi\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (0.7.1)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\sophi\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (0.5.13)
# Requirement already satisfied: testpath in c:\users\sophi\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (0.5.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\sophi\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (1.5.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\sophi\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (0.8.4)
# Requirement already satisfied: soupsieve>1.2 in c:\users\sophi\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (2.3.1)
# Requirement already satisfied: packaging in c:\users\sophi\anaconda3\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (21.3)
# Requirement already satisfied: webencodings in c:\users\sophi\anaconda3\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (0.5.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\sophi\anaconda3\lib\site-packages (from packaging->bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (3.0.4)
# Requirement already satisfied: pure-eval in c:\users\sophi\anaconda3\lib\site-packages (from stack-data->ipython>=5.3.0->cufflinks) (0.2.2)
# Requirement already satisfied: executing in c:\users\sophi\anaconda3\lib\site-packages (from stack-data->ipython>=5.3.0->cufflinks) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\sophi\anaconda3\lib\site-packages (from stack-data->ipython>=5.3.0->cufflinks) (2.0.5)
# Building wheels for collected packages: cufflinks
#   Building wheel for cufflinks (setup.py): started
#   Building wheel for cufflinks (setup.py): finished with status 'done'
#   Created wheel for cufflinks: filename=cufflinks-0.17.3-py3-none-any.whl size=68736 sha256=3dfdad0abf5e85e322927133c916e83d1db9b12af0d5d79cb98f74bb263d9110
#   Stored in directory: c:\users\sophi\appdata\local\pip\cache\wheels\29\b4\f8\2fd2206eeeba6ccad8167e4e8894b8c4ec27bf1342037fd136
# Successfully built cufflinks
# Installing collected packages: colorlover, cufflinks
# Successfully installed colorlover-0.3.0 cufflinks-0.17.3

# %%
import chart_studio.plotly as py
import plotly.figure_factory as ff
import pandas as pd 
from plotly.offline import plot 
from plotly import __version__
import cufflinks as cf

# %%
c= pd.read_csv('c.csv')

table= ff.create_table(c)
py.iplot(table, filename= 'juypter-table1')
# Out:
# ---------------------------------------------------------------------------
# PlotlyRequestError                        Traceback (most recent call last)
# Input In [5], in <cell line: 4>()
#       1 c= pd.read_csv('c.csv')
#       3 table= ff.create_table(c)
# ----> 4 py.iplot(table, filename= 'juypter-table1')
#
# File ~\anaconda3\lib\site-packages\chart_studio\plotly\plotly.py:135, in iplot(figure_or_data, **plot_options)
#     133 if "auto_open" not in plot_options:
#     134     plot_options["auto_open"] = False
# --> 135 url = plot(figure_or_data, **plot_options)
#     137 if isinstance(figure_or_data, dict):
#     138     layout = figure_or_data.get("layout", {})
#
# File ~\anaconda3\lib\site-packages\chart_studio\plotly\plotly.py:276, in plot(figure_or_data, validate, **plot_options)
#     273 else:
#     274     grid_filename = filename + "_grid"
# --> 276 grid_ops.upload(
#     277     grid=grid,
#     278     filename=grid_filename,
#     279     world_readable=payload["world_readable"],
#     280     auto_open=False,
#     281 )
#     283 _set_grid_column_references(figure, grid)
#     284 payload["figure"] = figure
#
# File ~\anaconda3\lib\site-packages\chart_studio\plotly\plotly.py:1087, in grid_ops.upload(cls, grid, filename, world_readable, auto_open, meta)
#    1084     if parent_path:
#    1085         payload["parent_path"] = parent_path
# -> 1087 file_info = _create_or_overwrite_grid(payload)
#    1089 cols = file_info["cols"]
#    1090 fid = file_info["fid"]
#
# File ~\anaconda3\lib\site-packages\chart_studio\plotly\plotly.py:1550, in _create_or_overwrite_grid(data, max_retries)
#    1548 # Create file
#    1549 try:
# -> 1550     res = api_module.create(data)
#    1551 except exceptions.PlotlyRequestError as e:
#    1552     if max_retries > 0 and "already exists" in e.message:
#    1553         # Retry _create_or_overwrite
#
# File ~\anaconda3\lib\site-packages\chart_studio\api\v2\grids.py:18, in create(body)
#      10 """
#      11 Create a new grid.
#      12
#    (...)
#      15
#      16 """
#      17 url = build_url(RESOURCE)
# ---> 18 return request("post", url, json=body)
#
# File ~\anaconda3\lib\site-packages\retrying.py:49, in retry.<locals>.wrap.<locals>.wrapped_f(*args, **kw)
#      47 @six.wraps(f)
#      48 def wrapped_f(*args, **kw):
# ---> 49     return Retrying(*dargs, **dkw).call(f, *args, **kw)
#
# File ~\anaconda3\lib\site-packages\retrying.py:206, in Retrying.call(self, fn, *args, **kwargs)
#     203     attempt = Attempt(tb, attempt_number, True)
#     205 if not self.should_reject(attempt):
# --> 206     return attempt.get(self._wrap_exception)
#     208 delay_since_first_attempt_ms = int(round(time.time() * 1000)) - start_time
#     209 if self.stop(attempt_number, delay_since_first_attempt_ms):
#
# File ~\anaconda3\lib\site-packages\retrying.py:247, in Attempt.get(self, wrap_exception)
#     245         raise RetryError(self)
#     246     else:
# --> 247         six.reraise(self.value[0], self.value[1], self.value[2])
#     248 else:
#     249     return self.value
#
# File ~\anaconda3\lib\site-packages\six.py:719, in reraise(tp, value, tb)
#     717     if value.__traceback__ is not tb:
#     718         raise value.with_traceback(tb)
# --> 719     raise value
#     720 finally:
#     721     value = None
#
# File ~\anaconda3\lib\site-packages\retrying.py:200, in Retrying.call(self, fn, *args, **kwargs)
#     198 while True:
#     199     try:
# --> 200         attempt = Attempt(fn(*args, **kwargs), attempt_number, False)
#     201     except:
#     202         tb = sys.exc_info()
#
# File ~\anaconda3\lib\site-packages\chart_studio\api\v2\utils.py:180, in request(method, url, **kwargs)
#     178     content = response.content if response else "No content"
#     179     raise exceptions.PlotlyRequestError(message, status_code, content)
# --> 180 validate_response(response)
#     181 return response
#
# File ~\anaconda3\lib\site-packages\chart_studio\api\v2\utils.py:82, in validate_response(response)
#      79 if not message:
#      80     message = content if content else "No Content"
# ---> 82 raise exceptions.PlotlyRequestError(message, status_code, content)
#
# PlotlyRequestError: Authentication credentials were not provided.

# %%
import plotly.express as px
fig = px.box(c, x="Group", y="Total",title = 'Group show results in different in SAT Total scores in campus level')
fig.show()
# Out:
# <div>                            <div id="9d70adc1-9d61-4794-82d0-cef08de87d6b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9d70adc1-9d61-4794-82d0-cef08de87d6b")) {                    Plotly.newPlot(                        "9d70adc1-9d61-4794-82d0-cef08de87d6b",                        [{"alignmentgroup":"True","hovertemplate":"Group=%{x}<br>Total=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x":["Asian","Multiracial","Missing Ethnicity","Asian","American Indian","Asian","White","Multiracial","Missing Ethnicity","Section 504","Multiracial","Missing Ethnicity","Asian","American Indian","Multiracial","Missing Ethnicity","Asian","White","Multiracial","Missing Ethnicity","Multiracial","Gifted","All Students","African American","American Indian","Asian","Hispanic","Pacific Islander","White","Multiracial","Missing Ethnicity","Economically Disadvantaged","Not Economically Disadvantaged","Missing Econ","Female","Male","Missing Gender","Bil/ESL","Not Bil/ESL","Missing Bil/ESL","CTE Concentrator","Not CTE Concentrator","Missing CTE","Gifted","Not Gifted","Missing Gifted","Section 504","Not Section 504","Missing Section 504","Special Ed","Not Special Ed","Missing Special Ed","Title1","Not Title1","Missing Title1","At-Risk","Not At-Risk","Missing At-Risk","Dyslexia","Not Dyslexia","Missing Dyslexia","EB/EL","Not EB/EL","Missing EB/EL","Foster Care","Not Foster Care","Missing Foster Care","Homeless","Not Homeless","Missing Homeless","Immigrant","Not Immigrant","Missing Immigrant","Migrant","Not Migrant","Missing Migrant","Military-Connected","Not Military-Connected","Missing Military-Connected","Asian","Hispanic","Pacific Islander","Multiracial","Missing Ethnicity","Title1","Homeless","American Indian","American Indian","Asian","Gifted","Homeless","Multiracial","Missing Ethnicity","Asian","White","Multiracial","Missing Ethnicity","Immigrant","Military-Connected","Military-Connected","Multiracial","Missing Ethnicity","White","Multiracial","Missing Ethnicity","Not Economically Disadvantaged","Missing Econ","Asian","Asian","Gifted","Military-Connected","Pacific Islander","Asian","Military-Connected","Special Ed","Immigrant","African American","American Indian","Asian","Gifted","Gifted","Gifted","American Indian","Asian","Gifted","White","Multiracial","Missing Ethnicity","Not Economically Disadvantaged","Missing Econ","Male","Missing Gender","Bil/ESL","Gifted","Section 504","Pacific Islander","Pacific Islander","American Indian","Gifted","Dyslexia","American Indian","Not CTE Concentrator","Missing CTE","Pacific Islander","American Indian","Immigrant","Asian","African American","American Indian","Asian","Gifted","White","Female","American Indian","Not CTE Concentrator","Missing CTE","Gifted","Gifted","Asian","Gifted","Multiracial","Missing Ethnicity","Military-Connected","Not CTE Concentrator","Missing CTE","Gifted","Gifted","Homeless","Section 504","Gifted","Gifted","Not CTE Concentrator","Missing CTE","Not CTE Concentrator","Missing CTE","Gifted","Not CTE Concentrator","Missing CTE","Asian","Special Ed","Military-Connected","African American","American Indian","Asian","Gifted","Multiracial","Missing Ethnicity","Gifted","Homeless","Military-Connected","Not CTE Concentrator","Missing CTE","Section 504","Gifted","Pacific Islander","Gifted","Title1","Homeless","Pacific Islander","Asian","Homeless","American Indian","Asian","Multiracial","Missing Ethnicity","Special Ed","White","Multiracial","Missing Ethnicity","Not Economically Disadvantaged","Gifted","Gifted","Multiracial","Missing Ethnicity","Homeless","American Indian","Dyslexia","Military-Connected","American Indian","Gifted","Special Ed","Migrant","Afri ...

# %%
d= pd.read_csv('d.csv')

table= ff.create_table(c)
py.iplot(table, filename= 'juypter-table2')
